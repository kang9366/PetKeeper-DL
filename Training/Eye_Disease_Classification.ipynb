# %% [markdown]
# <a href="https://colab.research.google.com/github/kang9366/PetKeeper_DeepLearning/blob/main/Training/Eye_Disease_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os
import pandas as pd

# display images
from torchvision import utils
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/data'

# %%
normal = os.listdir(path + '/정상')
conjunctivitis = os.listdir(path + '/결막염')
cataract = os.listdir(path + '/백내장 성숙')
blepharitis = os.listdir(path + '/안검염')
keratitis = os.listdir(path + '/색소침착성각막염')
entropion = os.listdir(path + '/안검내반증')
sclerosis = os.listdir(path + '/핵경화')
mastopathy = os.listdir(path + '/유루증')
nonUlcerative = os.listdir(path + '/비궤양성각막질환 상')
ulcerative = os.listdir(path + '/궤양성각막염 상')

data = {'class':[],'num':[]}
data['class'] += ['normal', 'conjunctivitis', 'cataract', 'blepharitis', 'keratitis', 'entropion', 'sclerosis', 'mastopathy', 'non-ulcerative', 'ulcerative']
data['num'] += [len(normal), len(conjunctivitis), len(cataract),
                len(blepharitis), len(keratitis), len(entropion),
                len(sclerosis), len(mastopathy), len(nonUlcerative), len(ulcerative)]

df = pd.DataFrame(data)
df

# %%
plt.figure(figsize=(13,6))
sns.barplot(x=df['class'],y=df['num'])
# Out:
# <Axes: xlabel='class', ylabel='num'>

# %%
classes = os.listdir(path)

plt.figure(figsize=(30 , 30))
for x in range(10):
    i = random.randint(0,10)                    # getting the class
    images = os.listdir(path+'/'+classes[i])
    j = random.randint(0,1000)                  # getting the image
    image = cv2.imread(path+'/'+classes[i]+'/'+images[j])
    print(path+'/'+classes[i]+'/'+images[j])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    ax = plt.subplot(5, 5, x + 1)
    plt.imshow(image)
    plt.title(classes[i])
    plt.axis("off")

plt.show()
# Out:
# /content/drive/MyDrive/data/색소침착성각막염/crop_D21_164ce4a7-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_3d507daf-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/백내장 성숙/crop_D51_03043d31-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_0e5e3aaa-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/비궤양성각막질환 상/crop_D40_18c0cfc4-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/결막염/crop_D32_3178def1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/궤양성각막염 상/crop_D27_3aad2f0f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/핵경화/crop_D12_3dabada6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/비궤양성각막질환 상/crop_D45_18a8c2a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/백내장 성숙/crop_D43_2f5f873d-60a5-11ec-8402-0a7404972c70.jpg
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4370 (\N{HANGUL CHOSEONG HIEUH}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4458 (\N{HANGUL JUNGSEONG WA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 데이터 증강

# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    


file_list = [path + '/정상', path + '/결막염', path + '/백내장 성숙', path + '/안검염', path + '/색소침착성각막염', path + '/안검내반증', path + '/핵경화', path + '/유루증', path + '/비궤양성각막질환 상', path + '/궤양성각막염 상']

for j in file_list:
  num_augmented_images = 10000-len(j)
  augment_cnt = 1
  file_names = os.listdir(j)
  for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, len(j)-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = j + '/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(j + '/inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(j + '/rotated_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save(j + '/noiseAdded_' + str(augment_cnt) + '.png')
        
    augment_cnt += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 21
# crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D21_1d0ac895-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# invert
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 10
# crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D36_12f6897c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 1
# crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_3d7cb751-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 26
# crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D46_13903b50-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70 (1).jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 27
# crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D50_3db20c47-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 25
# crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D53_03095647-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 6
# crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D11_03846ee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 28
# crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D47_3dc93929-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 20
# crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D33_10a5db07-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 18
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 22
# crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D27_3da7b9a3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D37_0e7d69c9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D5_1ce7c920-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D4_0e5a899c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 19
# crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D44_1ce18b49-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D14_1c401dca-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 24
# crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D23_3ded330e-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# /content/drive/MyDrive/data/안검염/crop_D43_0386d4d2-60a5-11ec-8402-0a7404972c70 (1).jpg
# noise
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D45_0dbbdb8d-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 23
# crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D40_3d7cad53-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 14
# crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D57_1c47bee3-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 7
# crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D1_0e61a46e-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D59_3de6d1d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 9
# crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D58_0dc3fbb3-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 2
# crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D0_3dc8b54c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 11
# crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D8_0e6e0dd6-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 8
# crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/안검염/crop_D16_11041193-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_3ddf63fe-60a5-11ec-8402-0a7404972c70.jpg
# ...
# invert
# 14
# crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 25
# crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 27
# crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 26
# crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D32_31e5c689-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D32_31e5c689-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 14
# crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 23
# crop_D6_3a8947e4-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D6_3a8947e4-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 14
# crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 32
# crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 12
# crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 8
# crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 30
# crop_D24_31e01245-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_31e01245-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 31
# crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D52_3226bc75-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D52_3226bc75-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 12
# crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D10_107e863a-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 27
# crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 34
# crop_D9_1109231f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_1109231f-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 29
# crop_D52_31dffc8a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D52_31dffc8a-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 18
# crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 32
# crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 32
# crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 26
# crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 19
# crop_D35_0ea0d7a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_0ea0d7a8-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 2
# crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 34
# crop_D9_1109231f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_1109231f-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 15
# crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 30
# crop_D24_31e01245-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_31e01245-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 8
# crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D41_107fc81c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 33
# crop_D35_3232e9d7-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_3232e9d7-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 18
# crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D38_10fc87a2-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 20
# crop_D32_31e5c689-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D32_31e5c689-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 22
# crop_D19_31fe931b-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D19_31fe931b-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 11
# crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_117dcdef-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 28
# crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 25
# crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D34_321a0fc9-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 9
# crop_D3_325248be-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D3_325248be-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 15
# crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 28
# crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 31
# crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 24
# crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 33
# crop_D35_3232e9d7-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_3232e9d7-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 4
# crop_D16_191a1f8a-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D16_191a1f8a-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 14
# crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_386bc897-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 31
# crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 10
# crop_D9_19e4bd29-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_19e4bd29-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 7
# crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D46_324b8fc0-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 9
# crop_D3_325248be-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D3_325248be-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 16
# crop_D9_31d0f42c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_31d0f42c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 16
# crop_D9_31d0f42c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_31d0f42c-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 3
# crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_1044f71b-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 28
# crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_31cdc941-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 21
# crop_D22_32196b83-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_32196b83-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 2
# crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D28_31ce40a8-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 27
# crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D19_1cbfc00f-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 32
# crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 15
# crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D47_31b78c73-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 6
# crop_D52_3226bc75-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D52_3226bc75-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 31
# crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 17
# crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D0_3ace5dcd-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 26
# crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D50_386b9570-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 10
# crop_D9_19e4bd29-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D9_19e4bd29-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 32
# crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D33_39d6b3d9-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 19
# crop_D35_0ea0d7a8-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D35_0ea0d7a8-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 31
# crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D22_0ea561de-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# rotate
# 13
# crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D24_186b587c-60a5-11ec-8402-0a7404972c70.jpg
# invert
# 5
# crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D27_32285f66-60a5-11ec-8402-0a7404972c70.jpg
# noise
# 24
# crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg
# /content/drive/MyDrive/data/색소침착성각막염/crop_D54_129522d1-60a5-11ec-8402-0a7404972c70.jpg

# %% [markdown]
# # 데이터 불러오기

# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader, random_split

dataset = ImageFolder('/content/drive/MyDrive/data',
                      transform=transforms.Compose([transforms.RandomCrop(96), transforms.ToTensor()]))

train_size = int(0.7 * len(dataset))
test_size = len(dataset) - train_size

train, validation = random_split(dataset, [train_size, test_size])

# %%
print(len(train))
print(len(validation))
# Out:
# 75726
# 32454

# %%
train_dl = DataLoader(train, batch_size=32, shuffle=True)
val_dl = DataLoader(validation, batch_size=32, shuffle=True)

# %%
print(dataset.classes)
# Out:
# ['결막염', '궤양성각막염 상', '궤양성각막염 하', '백내장 비성숙', '백내장 성숙', '백내장 초기', '비궤양성각막질환 상', '비궤양성각막질환 하', '색소침착성각막염', '안검내반증', '안검염', '안검종양', '유루증', '정상', '핵경화']

# %% [markdown]
# # MobileNet

# %%
# Depthwise Separable Convolution
class Depthwise(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.depthwise = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, 3, stride=stride, padding=1, groups=in_channels, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.ReLU6(),
        )

        self.pointwise = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU6()
        )
    
    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x

# %%
# Basic Conv2d
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, **kwargs):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, **kwargs),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
# MobileNetV1
class MobileNet(nn.Module):
    def __init__(self, width_multiplier, num_classes=2, init_weights=True):
        super().__init__()
        self.init_weights=init_weights
        alpha = width_multiplier

        self.conv1 = BasicConv2d(3, int(32*alpha), 3, stride=2, padding=1)
        self.conv2 = Depthwise(int(32*alpha), int(64*alpha), stride=1)
        # down sample
        self.conv3 = nn.Sequential(
            Depthwise(int(64*alpha), int(128*alpha), stride=2),
            Depthwise(int(128*alpha), int(128*alpha), stride=1)
        )
        # down sample
        self.conv4 = nn.Sequential(
            Depthwise(int(128*alpha), int(256*alpha), stride=2),
            Depthwise(int(256*alpha), int(256*alpha), stride=1)
        )
        # down sample
        self.conv5 = nn.Sequential(
            Depthwise(int(256*alpha), int(512*alpha), stride=2),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
        )
        # down sample
        self.conv6 = nn.Sequential(
            Depthwise(int(512*alpha), int(1024*alpha), stride=2)
        )
        # down sample
        self.conv7 = nn.Sequential(
            Depthwise(int(1024*alpha), int(1024*alpha), stride=2)
        )

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(int(1024*alpha), num_classes)

        # weights initialization
        if self.init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    # weights initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def mobilenet(alpha=1, num_classes=2):
    return MobileNet(alpha, num_classes)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
x = torch.randn((3, 3, 224, 224)).to(device)
model = mobilenet(alpha=1).to(device)
output = model(x)
print('output size:', output.size())
# Out:
# output size: torch.Size([3, 2])

# %%
summary(model, (3, 224, 224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             896
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#               ReLU-3         [-1, 32, 112, 112]               0
#        BasicConv2d-4         [-1, 32, 112, 112]               0
#             Conv2d-5         [-1, 32, 112, 112]             288
#        BatchNorm2d-6         [-1, 32, 112, 112]              64
#              ReLU6-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]           2,048
#        BatchNorm2d-9         [-1, 64, 112, 112]             128
#             ReLU6-10         [-1, 64, 112, 112]               0
#         Depthwise-11         [-1, 64, 112, 112]               0
#            Conv2d-12           [-1, 64, 56, 56]             576
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#             ReLU6-14           [-1, 64, 56, 56]               0
#            Conv2d-15          [-1, 128, 56, 56]           8,192
#       BatchNorm2d-16          [-1, 128, 56, 56]             256
#             ReLU6-17          [-1, 128, 56, 56]               0
#         Depthwise-18          [-1, 128, 56, 56]               0
#            Conv2d-19          [-1, 128, 56, 56]           1,152
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#             ReLU6-21          [-1, 128, 56, 56]               0
#            Conv2d-22          [-1, 128, 56, 56]          16,384
#       BatchNorm2d-23          [-1, 128, 56, 56]             256
#             ReLU6-24          [-1, 128, 56, 56]               0
#         Depthwise-25          [-1, 128, 56, 56]               0
#            Conv2d-26          [-1, 128, 28, 28]           1,152
#       BatchNorm2d-27          [-1, 128, 28, 28]             256
#             ReLU6-28          [-1, 128, 28, 28]               0
#            Conv2d-29          [-1, 256, 28, 28]          32,768
#       BatchNorm2d-30          [-1, 256, 28, 28]             512
#             ReLU6-31          [-1, 256, 28, 28]               0
#         Depthwise-32          [-1, 256, 28, 28]               0
#            Conv2d-33          [-1, 256, 28, 28]           2,304
#       BatchNorm2d-34          [-1, 256, 28, 28]             512
#             ReLU6-35          [-1, 256, 28, 28]               0
#            Conv2d-36          [-1, 256, 28, 28]          65,536
#       BatchNorm2d-37          [-1, 256, 28, 28]             512
#             ReLU6-38          [-1, 256, 28, 28]               0
#         Depthwise-39          [-1, 256, 28, 28]               0
#            Conv2d-40          [-1, 256, 14, 14]           2,304
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#             ReLU6-42          [-1, 256, 14, 14]               0
#            Conv2d-43          [-1, 512, 14, 14]         131,072
#       BatchNorm2d-44          [-1, 512, 14, 14]           1,024
#             ReLU6-45          [-1, 512, 14, 14]               0
#         Depthwise-46          [-1, 512, 14, 14]               0
#            Conv2d-47          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-48          [-1, 512, 14, 14]           1,024
#             ReLU6-49          [-1, 512, 14, 14]               0
#            Conv2d-50          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-51          [-1, 512, 14, 14]           1,024
#             ReLU6-52          [-1, 512, 14, 14]               0
#         Depthwise-53          [-1, 512, 14, 14]               0
#            Conv2d-54          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-55          [-1, 512, 14, 14]           1,024
#             ReLU6-56          [-1, 512, 14, 14]               0
#            Conv2d-57          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-58          [-1, 512, 14, 14]           1,024
#             ReLU6-59          [-1, 512, 14, 14]               0
#         Depthwise-60          [-1, 512, 14, 14]               0
#            Conv2d-61          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-62          [-1, 512, 14, 14]           1,024
#             ReLU6-63          [-1, 512, 14, 14]               0
#            Conv2d-64          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-65          [-1, 512, 14, 14]           1,024
#             ReLU6-66          [-1, 512, 14, 14]               0
#         Depthwise-67          [-1, 512, 14, 14]               0
#            Conv2d-68          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-69          [-1, 512, 14, 14]           1,024
#             ReLU6-70          [-1, 512, 14, 14]               0
#            Conv2d-71          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-72          [-1, 512, 14, 14]           1,024
#             ReLU6-73          [-1, 512, 14, 14]               0
#         Depthwise-74          [-1, 512, 14, 14]               0
#            Conv2d-75          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-76          [-1, 512, 14, 14]           1,024
#             ReLU6-77          [-1, 512, 14, 14]               0
#            Conv2d-78          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-79          [-1, 512, 14, 14]           1,024
#             ReLU6-80          [-1, 512, 14, 14]               0
#         Depthwise-81          [-1, 512, 14, 14]               0
#            Conv2d-82            [-1, 512, 7, 7]           4,608
#       BatchNorm2d-83            [-1, 512, 7, 7]           1,024
#             ReLU6-84            [-1, 512, 7, 7]               0
#            Conv2d-85           [-1, 1024, 7, 7]         524,288
#       BatchNorm2d-86           [-1, 1024, 7, 7]           2,048
#             ReLU6-87           [-1, 1024, 7, 7]               0
#         Depthwise-88           [-1, 1024, 7, 7]               0
#            Conv2d-89           [-1, 1024, 4, 4]           9,216
#       BatchNorm2d-90           [-1, 1024, 4, 4]           2,048
#             ReLU6-91           [-1, 1024, 4, 4]               0
#            Conv2d-92           [-1, 1024, 4, 4]       1,048,576
#       BatchNorm2d-93           [-1, 1024, 4, 4]           2,048
#             ReLU6-94           [-1, 1024, 4, 4]               0
#         Depthwise-95           [-1, 1024, 4, 4]               0
# AdaptiveAvgPool2d-96           [-1, 1024, 1, 1]               0
#            Linear-97                    [-1, 2]           2,050
# ================================================================
# Total params: 3,209,058
# Trainable params: 3,209,058
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 137.36
# Params size (MB): 12.24
# Estimated Total Size (MB): 150.17
# ----------------------------------------------------------------

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':40,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.772127, val loss: 0.722448, accuracy: 63.94, time: 0.2230 min
# ----------
# Epoch 1/39, current lr= 0.01
# train loss: 0.504957, val loss: 1.054457, accuracy: 65.88, time: 0.4290 min
# ----------
# Epoch 2/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.452284, val loss: 0.460766, accuracy: 82.39, time: 0.6430 min
# ----------
# Epoch 3/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.434545, val loss: 0.449064, accuracy: 78.50, time: 0.8669 min
# ----------
# Epoch 4/39, current lr= 0.01
# train loss: 0.381259, val loss: 0.912483, accuracy: 63.80, time: 1.1147 min
# ----------
# Epoch 5/39, current lr= 0.01
# train loss: 0.407009, val loss: 0.502549, accuracy: 77.39, time: 1.3287 min
# ----------
# Epoch 6/39, current lr= 0.01
# train loss: 0.370083, val loss: 0.771078, accuracy: 58.25, time: 1.5412 min
# ----------
# Epoch 7/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.386745, val loss: 0.315626, accuracy: 88.21, time: 1.7562 min
# ----------
# Epoch 8/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.361128, val loss: 0.299821, accuracy: 86.96, time: 1.9698 min
# ----------
# Epoch 9/39, current lr= 0.01
# train loss: 0.322450, val loss: 0.475726, accuracy: 80.44, time: 2.1861 min
# ----------
# Epoch 10/39, current lr= 0.01
# train loss: 0.336436, val loss: 0.352276, accuracy: 86.55, time: 2.4015 min
# ----------
# Epoch 11/39, current lr= 0.01
# train loss: 0.347573, val loss: 0.421691, accuracy: 81.55, time: 2.6129 min
# ----------
# Epoch 12/39, current lr= 0.01
# train loss: 0.321629, val loss: 0.458526, accuracy: 78.78, time: 2.8400 min
# ----------
# Epoch 13/39, current lr= 0.01
# train loss: 0.317178, val loss: 0.422924, accuracy: 81.28, time: 3.0444 min
# ----------
# Epoch 14/39, current lr= 0.01
# train loss: 0.293157, val loss: 0.345719, accuracy: 86.55, time: 3.2571 min
# ----------
# Epoch 15/39, current lr= 0.01
# train loss: 0.331871, val loss: 0.400288, accuracy: 81.41, time: 3.6235 min
# ----------
# Epoch 16/39, current lr= 0.01
# train loss: 0.320103, val loss: 0.311246, accuracy: 87.79, time: 3.8376 min
# ----------
# Epoch 17/39, current lr= 0.01
# train loss: 0.257288, val loss: 1.084862, accuracy: 69.07, time: 4.0455 min
# ----------
# Epoch 18/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.280848, val loss: 0.224131, accuracy: 91.12, time: 4.2544 min
# ----------
# Epoch 19/39, current lr= 0.01
# train loss: 0.240894, val loss: 0.308162, accuracy: 88.63, time: 4.4671 min
# ----------
# Epoch 20/39, current lr= 0.01
# train loss: 0.262393, val loss: 0.607404, accuracy: 66.85, time: 4.6826 min
# ----------
# Epoch 21/39, current lr= 0.01
# train loss: 0.271848, val loss: 0.467808, accuracy: 80.72, time: 4.9000 min
# ----------
# Epoch 22/39, current lr= 0.01
# train loss: 0.283697, val loss: 0.495687, accuracy: 81.14, time: 5.1466 min
# ----------
# Epoch 23/39, current lr= 0.01
# train loss: 0.252958, val loss: 0.313795, accuracy: 86.82, time: 5.3743 min
# ----------
# Epoch 24/39, current lr= 0.01
# train loss: 0.221861, val loss: 0.433999, accuracy: 80.17, time: 5.5854 min
# ----------
# Epoch 25/39, current lr= 0.01
# train loss: 0.224467, val loss: 0.244963, accuracy: 91.40, time: 5.7994 min
# ----------
# Epoch 26/39, current lr= 0.01
# train loss: 0.255520, val loss: 0.336651, accuracy: 86.13, time: 6.0129 min
# ----------
# Epoch 27/39, current lr= 0.01
# train loss: 0.228839, val loss: 0.224193, accuracy: 91.82, time: 6.2260 min
# ----------
# Epoch 28/39, current lr= 0.01
# train loss: 0.228694, val loss: 0.276024, accuracy: 89.04, time: 6.4365 min
# ----------
# Epoch 29/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.259943, val loss: 0.192903, accuracy: 93.34, time: 6.6441 min
# ----------
# Epoch 30/39, current lr= 0.01
# train loss: 0.245799, val loss: 0.208704, accuracy: 91.96, time: 6.8544 min
# ----------
# Epoch 31/39, current lr= 0.01
# train loss: 0.229576, val loss: 0.354001, accuracy: 88.21, time: 7.0673 min
# ----------
# Epoch 32/39, current lr= 0.01
# train loss: 0.234709, val loss: 0.200719, accuracy: 91.82, time: 7.3017 min
# ----------
# Epoch 33/39, current lr= 0.01
# train loss: 0.206150, val loss: 0.211454, accuracy: 92.79, time: 7.5241 min
# ----------
# Epoch 34/39, current lr= 0.01
# train loss: 0.210545, val loss: 0.201380, accuracy: 93.62, time: 7.7488 min
# ----------
# Epoch 35/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.227538, val loss: 0.181947, accuracy: 92.09, time: 7.9633 min
# ----------
# Epoch 36/39, current lr= 0.01
# train loss: 0.229970, val loss: 0.242103, accuracy: 90.43, time: 8.1763 min
# ----------
# Epoch 37/39, current lr= 0.01
# train loss: 0.230177, val loss: 0.248770, accuracy: 90.43, time: 8.3912 min
# ----------
# Epoch 38/39, current lr= 0.01
# train loss: 0.226462, val loss: 0.312786, accuracy: 87.10, time: 8.6062 min
# ----------
# Epoch 39/39, current lr= 0.01
# train loss: 0.226321, val loss: 0.244142, accuracy: 89.46, time: 8.8215 min
# ----------

# %%
# train-val progress
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylim([0,1])
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot accuracy progress
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylim([0,1])
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# %%
path
# Out:
# '/content/drive/MyDrive/data'

# %%
model = MobileNet(1, 2) # 모델 선언 시의 파라미터 조건이 있던 경우 같이 추가
model.load_state_dict(torch.load(path + '/weights.pt'))
model.eval()

# %%
from PIL import Image

image_transforms = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
])

da = os.listdir(path + '/ttest')
da

for i in da:
  image = Image.open(path + '/ttest/' + i)
  image_tensor = image_transforms(image).unsqueeze(0)

  with torch.no_grad():
    output = model(image_tensor)

  _, predicted = torch.max(output.data, 1)
  print('Predicted:', dataset.classes[predicted.item()])
# Out:
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis
# Predicted: conjunctivitis

# %%
dataset.classes
# Out:
# ['conjunctivitis', 'normal']

# %% [markdown]
# # ResNet

# %%
# import package

# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim
from torch.optim.lr_scheduler import StepLR

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %%
class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        # BatchNorm에 bias가 포함되어 있으므로, conv2d는 bias=False로 설정합니다.
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels * BasicBlock.expansion, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels * BasicBlock.expansion),
        )

        # identity mapping, input과 output의 feature map size, filter 수가 동일한 경우 사용.
        self.shortcut = nn.Sequential()

        self.relu = nn.ReLU()

        # projection mapping using 1x1conv
        if stride != 1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BasicBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels * BasicBlock.expansion)
            )

    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x


class BottleNeck(nn.Module):
    expansion = 4
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels * BottleNeck.expansion, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion),
        )

        self.shortcut = nn.Sequential()

        self.relu = nn.ReLU()

        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels*BottleNeck.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels*BottleNeck.expansion)
            )
            
    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=2, init_weights=True):
        super().__init__()

        self.in_channels=64

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        self.conv2_x = self._make_layer(block, 64, num_block[0], 1)
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2)
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2)
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # weights inittialization
        if init_weights:
            self._initialize_weights()

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion

        return nn.Sequential(*layers)

    def forward(self,x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        x = self.conv3_x(output)
        x = self.conv4_x(x)
        x = self.conv5_x(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

    # define weight initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def resnet18():
    return ResNet(BasicBlock, [2,2,2,2])

def resnet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

def resnet50():
    return ResNet(BottleNeck, [3,4,6,3])

def resnet101():
    return ResNet(BottleNeck, [3, 4, 23, 3])

def resnet152():
    return ResNet(BottleNeck, [3, 8, 36, 3])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = resnet50().to(device)
x = torch.randn(3, 3, 224, 224).to(device)
output = model(x)
print(output.size())
# Out:
# torch.Size([3, 2])

# %%
summary(model, (3, 224, 224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        BottleNeck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        BottleNeck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        BottleNeck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        BottleNeck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        BottleNeck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        BottleNeck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        BottleNeck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        BottleNeck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       BottleNeck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       BottleNeck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       BottleNeck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       BottleNeck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       BottleNeck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       BottleNeck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       BottleNeck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       BottleNeck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                    [-1, 2]           4,098
# ================================================================
# Total params: 23,512,130
# Trainable params: 23,512,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 89.69
# Estimated Total Size (MB): 376.82
# ----------------------------------------------------------------

# %%
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.001)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

# %%
# function to calculate metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# function to calculate loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %%
# function to calculate loss and metric per epoch
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b
        
        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data

    return loss, metric

# %%
# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    # # GPU out of memoty error
    # best_model_wts = copy.deepcopy(model.state_dict())

    best_loss = float('inf')

    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            # best_model_wts = copy.deepcopy(model.state_dict())

            # torch.save(model.state_dict(), path2weights)
            # print('Copied best model weights!')
            print('Get best val_loss')

        lr_scheduler.step(val_loss)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    # model.load_state_dict(best_model_wts)

    return model, loss_history, metric_history

# %%
# definc the training parameters
params_train = {
    'num_epochs':40,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# create the directory that stores weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/39, current lr=0.001
# Get best val_loss
# train loss: 0.745957, val loss: 0.617264, accuracy: 72.26, time: 0.2717 min
# ----------
# Epoch 1/39, current lr=0.001
# train loss: 0.430108, val loss: 0.682849, accuracy: 73.79, time: 0.5513 min
# ----------
# Epoch 2/39, current lr=0.001
# Get best val_loss
# train loss: 0.396262, val loss: 0.576598, accuracy: 71.01, time: 0.8235 min
# ----------
# Epoch 3/39, current lr=0.001
# train loss: 0.424522, val loss: 0.876691, accuracy: 58.39, time: 1.1027 min
# ----------
# Epoch 4/39, current lr=0.001
# Get best val_loss
# train loss: 0.400004, val loss: 0.467938, accuracy: 77.53, time: 1.3741 min
# ----------
# Epoch 5/39, current lr=0.001
# train loss: 0.379099, val loss: 0.508822, accuracy: 78.09, time: 1.6522 min
# ----------
# Epoch 6/39, current lr=0.001
# train loss: 0.380911, val loss: 0.599303, accuracy: 79.75, time: 1.9166 min
# ----------
# Epoch 7/39, current lr=0.001
# Get best val_loss
# train loss: 0.389345, val loss: 0.413076, accuracy: 81.28, time: 2.1957 min
# ----------
# Epoch 8/39, current lr=0.001
# train loss: 0.384220, val loss: 0.496480, accuracy: 78.92, time: 2.4729 min
# ----------
# Epoch 9/39, current lr=0.001
# Get best val_loss
# train loss: 0.352827, val loss: 0.308318, accuracy: 89.18, time: 2.7629 min
# ----------
# Epoch 10/39, current lr=0.001
# train loss: 0.346391, val loss: 0.534114, accuracy: 77.39, time: 3.0311 min
# ----------
# Epoch 11/39, current lr=0.001
# train loss: 0.335534, val loss: 0.675166, accuracy: 73.93, time: 3.2963 min
# ----------
# Epoch 12/39, current lr=0.001
# train loss: 0.326576, val loss: 0.583798, accuracy: 78.50, time: 3.5594 min
# ----------
# Epoch 13/39, current lr=0.001
# train loss: 0.362341, val loss: 0.320139, accuracy: 86.41, time: 3.8233 min
# ----------
# Epoch 14/39, current lr=0.001
# train loss: 0.310601, val loss: 0.441522, accuracy: 82.80, time: 4.0887 min
# ----------
# Epoch 15/39, current lr=0.001
# train loss: 0.293845, val loss: 0.367542, accuracy: 84.74, time: 4.3614 min
# ----------
# Epoch 16/39, current lr=0.001
# train loss: 0.293618, val loss: 0.358176, accuracy: 83.91, time: 4.6359 min
# ----------
# Epoch 17/39, current lr=0.001
# Get best val_loss
# train loss: 0.275505, val loss: 0.279447, accuracy: 88.77, time: 4.9050 min
# ----------
# Epoch 18/39, current lr=0.001
# train loss: 0.273407, val loss: 0.307578, accuracy: 87.24, time: 5.1702 min
# ----------
# Epoch 19/39, current lr=0.001
# train loss: 0.288292, val loss: 0.298484, accuracy: 87.38, time: 5.4338 min
# ----------
# Epoch 20/39, current lr=0.001
# Get best val_loss
# train loss: 0.281784, val loss: 0.227620, accuracy: 91.82, time: 5.7019 min
# ----------
# Epoch 21/39, current lr=0.001
# train loss: 0.291804, val loss: 0.457289, accuracy: 81.55, time: 5.9683 min
# ----------
# Epoch 22/39, current lr=0.001
# train loss: 0.313854, val loss: 0.537663, accuracy: 80.17, time: 6.2398 min
# ----------
# Epoch 23/39, current lr=0.001
# train loss: 0.305894, val loss: 0.335171, accuracy: 85.71, time: 6.5119 min
# ----------
# Epoch 24/39, current lr=0.001
# train loss: 0.300522, val loss: 0.304314, accuracy: 89.46, time: 6.7830 min
# ----------
# Epoch 25/39, current lr=0.001
# train loss: 0.309149, val loss: 0.270708, accuracy: 90.43, time: 7.0765 min
# ----------
# Epoch 26/39, current lr=0.001
# train loss: 0.280388, val loss: 0.452097, accuracy: 80.72, time: 7.3438 min
# ----------
# Epoch 27/39, current lr=0.001
# train loss: 0.269239, val loss: 0.450580, accuracy: 83.08, time: 7.6096 min
# ----------
# Epoch 28/39, current lr=0.001
# train loss: 0.260879, val loss: 0.547316, accuracy: 80.31, time: 7.8779 min
# ----------
# Epoch 29/39, current lr=0.001
# train loss: 0.293640, val loss: 0.340779, accuracy: 86.41, time: 8.1429 min
# ----------
# Epoch 30/39, current lr=0.001
# train loss: 0.247217, val loss: 0.250957, accuracy: 90.98, time: 8.4131 min
# ----------
# Epoch 31/39, current lr=0.001
# train loss: 0.259619, val loss: 0.837052, accuracy: 76.28, time: 8.6877 min
# ----------
# Epoch 32/39, current lr=0.0001
# train loss: 0.262299, val loss: 0.232555, accuracy: 91.12, time: 8.9579 min
# ----------
# Epoch 33/39, current lr=0.0001
# Get best val_loss
# train loss: 0.230261, val loss: 0.213800, accuracy: 92.23, time: 9.2210 min
# ----------
# Epoch 34/39, current lr=0.0001
# Get best val_loss
# train loss: 0.229597, val loss: 0.186687, accuracy: 93.62, time: 9.4866 min
# ----------
# Epoch 35/39, current lr=0.0001
# train loss: 0.205819, val loss: 0.221407, accuracy: 91.54, time: 9.7532 min
# ----------
# Epoch 36/39, current lr=0.0001
# train loss: 0.203334, val loss: 0.198845, accuracy: 92.93, time: 10.0176 min
# ----------
# Epoch 37/39, current lr=0.0001
# Get best val_loss
# train loss: 0.198156, val loss: 0.159074, accuracy: 94.45, time: 10.2857 min
# ----------
# Epoch 38/39, current lr=0.0001
# train loss: 0.194435, val loss: 0.194182, accuracy: 92.65, time: 10.5559 min
# ----------
# Epoch 39/39, current lr=0.0001
# train loss: 0.193033, val loss: 0.181250, accuracy: 93.34, time: 10.8296 min
# ----------

# %%
# train-val progress
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylim([0,1])
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot accuracy progress
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylim([0,1])
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# %%
from torchviz import make_dot
from torch.autograd import Variable

make_dot(model(torch.zeros([3, 3, 3, 32])), params=dict(model.named_parameters())).render("graph", format="png")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-50-307e3268a7e3> in <cell line: 4>()
#       2 from torch.autograd import Variable
#       3
# ----> 4 make_dot(model(torch.zeros([3, 3, 3, 32])), params=dict(model.named_parameters())).render("graph", format="png")
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-29-9d3bb7be3d41> in forward(self, x)
#      34
#      35     def forward(self,x):
# ---> 36         output = self.conv1(x)
#      37         output = self.conv2_x(output)
#      38         x = self.conv3_x(output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (conv2_x): Sequential(
#     (0): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (2): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#   )
#   (conv3_x): Sequential(
#     (0): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (2): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (3): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#   )
#   (conv4_x): Sequential(
#     (0): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (2): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (3): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (4): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (5): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#   )
#   (conv5_x): Sequential(
#     (0): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#     (2): BottleNeck(
#       (residual_function): Sequential(
#         (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#       (relu): ReLU()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )
